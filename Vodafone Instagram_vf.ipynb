# %% [markdown]
# ### Web Scapping Instagram

# %%
import requests
import re
import json
import logging
import pandas
from collections import OrderedDict
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
import numpy as np
import time
import logging
from collections import OrderedDict
from tqdm import tqdm_notebook as tqdm
from random import seed
from random import randint
from datetime import datetime
from webdriver_manager.chrome import ChromeDriverManager
from time import time       # Other imports
from time import sleep
import csv
from tqdm import tqdm_notebook as tqdm
from random import seed
from random import randint
from datetime import datetime
from selenium import webdriver
from urllib.request import urlopen
import json
from pandas.io.json import json_normalize
import pandas as pd, numpy as np
from time import sleep

# %%
def get_bs(session, url):
    """Makes a GET requests using the given Session object
    and returns a BeautifulSoup object.
    """
    r = None
    while True:
        r = session.get(url)
        if r.ok:
            break
    return BeautifulSoup(r.text, 'lxml')

# %% [markdown]
# #### Open the web browser

# %%
driver  = webdriver.Chrome("C:/Users/GSantos/Documents/GABRIEL RAVI/Web Scrapping/chromedriver_win32_2/chromedriver.exe")

# %%
username='tiagopires98'
driver.get('https://www.instagram.com/'+username+'/?hl=en')
url = 'https://www.instagram.com/' + username

# %% [markdown]
# ### Listagem Empresas

# %%
base_url = 'https://www.instagram.com/'

# %%
ig = pd.read_excel('Lista_Ravi_Insta.xlsx')

ig['posts'] = ig['Link']
# fb.shape

# %%
ig
# Out:
#     Setor        Categoria    Empresa  \
# 0  Beleza  Fisioculturismo  Tiago CIA
#
#                                             Link  \
# 0  https://www.instagram.com/tiagopires98/?hl=en
#
#                                            posts
# 0  https://www.instagram.com/tiagopires98/?hl=en

# %% [markdown]
# ### Scroll

# %%
from time import sleep

# %%
# # Selenium script to scroll to the bottom, wait 3 seconds for the next batch of data to load, then continue scrolling.  It will continue to do this until the page stops loading new data.
# lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
# match=False
# while(match==False):
#     lastCount = lenOfPage
#     sleep(3)
#     lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
#     if lastCount==lenOfPage:
#         match=True

# # Now that the page is fully scrolled, grab the source code.
# source_data = driver.page_source

# # Throw your source into BeautifulSoup and start parsing!
# bs_data = bs(source_data)

# %%
def posts_urls() -> None:
        """Taking the URLs from posts and appending in self.links"""
        elements = driver.find_elements_by_xpath('//a[@href]')
        teste = []
        for elem in elements:
            urls = elem.get_attribute('href')
            teste.append(urls)

# %%
from time import sleep

# %%
#Old

# def scroll_down(driver) -> None:
#         """Scrolling down the page and taking the URLs"""
#         last_height = 0

#         while True:
#             driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
#             sleep(5)
#             posts_urls()
#             new_height = driver.execute_script("return document.body.scrollHeight")
#             if new_height == last_height:
#                 break
#             last_height = new_height
#             posts_urls()

# %%
def get_href() -> None:
        elements = driver.find_elements_by_xpath('//a[@href]')
        for elem in elements:
            urls = elem.get_attribute('href')
            if 'p' in urls.split('/'):
                links.append(urls)

# %%
listona = []
listona2= []

# %%
def scroll_down(driver) -> None:
        """Scrolling down the page and taking the URLs"""
        global listona
        global listona2
        listona = []
        listona2 = []
        post_url = []
        last_height = 0
        while True:
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            sleep(5)
            elements = driver.find_elements_by_xpath('//a[@href]')
                       
            for elem in elements:
                urls = elem.get_attribute('href')
                listona.append(urls)    
                
            new_height = driver.execute_script("return document.body.scrollHeight")
            
            if new_height == last_height:
                break
            last_height = new_height
            
            listona2 += listona
            
listona_zord = list(dict.fromkeys(listona2))
posts_url = [ x for x in listona_zord if "https://www.instagram.com/p/" in x ]

# %%
scroll_down(driver)

# %%
posts_url
# Out:
# ['https://www.instagram.com/p/CJMNf2hhbC3/',
#  'https://www.instagram.com/p/CFkz0gJhL4a/',
#  'https://www.instagram.com/p/CDgFnmOBZ3d/',
#  'https://www.instagram.com/p/CCCXjoGh_-B/',
#  'https://www.instagram.com/p/CB_iFHRBpBM/',
#  'https://www.instagram.com/p/CBnXV9-BoCL/',
#  'https://www.instagram.com/p/B-Cy6V5BHdQ/',
#  'https://www.instagram.com/p/B9u6P9FhojH/',
#  'https://www.instagram.com/p/B9kAcgAB2U1/',
#  'https://www.instagram.com/p/B8jzvIbhXrd/',
#  'https://www.instagram.com/p/B8gJYX3hZOZ/',
#  'https://www.instagram.com/p/B8ek78khRMd/',
#  'https://www.instagram.com/p/B6h_CWhhKrH/',
#  'https://www.instagram.com/p/B5ydqOnBrI2/',
#  'https://www.instagram.com/p/B5TSvTPhdT3/',
#  'https://www.instagram.com/p/B2XHOfvh-NX/',
#  'https://www.instagram.com/p/B1VyXJQBpy_/',
#  'https://www.instagram.com/p/B1RcZKoBGcv/',
#  'https://www.instagram.com/p/B0y1DJhB1JI/',
#  'https://www.instagram.com/p/B0HQtxoBirG/',
#  'https://www.instagram.com/p/BzyTUR3hqwT/',
#  'https://www.instagram.com/p/BztfG4WBD2Q/',
#  'https://www.instagram.com/p/ByQRpgthbao/',
#  'https://www.instagram.com/p/Bu4jvdchUkE/',
#  'https://www.instagram.com/p/Bt3wi_ZBXCi/',
#  'https://www.instagram.com/p/BtCWUGxhDkd/',
#  'https://www.instagram.com/p/Brgf1Ifhyf7/',
#  'https://www.instagram.com/p/BoCcSIrB8rX/',
#  'https://www.instagram.com/p/BnTlNqdhoQq/',
#  'https://www.instagram.com/p/BmorLswBgMQ/',
#  'https://www.instagram.com/p/BlTzV8eBnM9/',
#  'https://www.instagram.com/p/BlKy45fBtb4/',
#  'https://www.instagram.com/p/BkIrLkdBgXV/',
#  'https://www.instagram.com/p/BjXdL9wB4m4/',
#  'https://www.instagram.com/p/BjSmtMAhSSH/',
#  'https://www.instagram.com/p/BjDKMKPho9I/',
#  'https://www.instagram.com/p/Biy2HepBDqx/',
#  'https://www.instagram.com/p/BiDCd7ch259/',
#  'https://www.instagram.com/p/Bh2JNNahxjH/',
#  'https://www.instagram.com/p/BgcFfIYlpBw/',
#  'https://www.instagram.com/p/BgR6UaglcxJ/',
#  'https://www.instagram.com/p/BeykiYSjlmO/',
#  'https://www.instagram.com/p/BeQsaodjtlK/',
#  'https://www.instagram.com/p/BeK1mCtDVv8/',
#  'https://www.instagram.com/p/BdlY8tEjmB9/',
#  'https://www.instagram.com/p/Bbpm0KMD_E-/',
#  'https://www.instagram.com/p/BatgQtVDLka/',
#  'https://www.instagram.com/p/BaUw9B1Fz3W/',
#  'https://www.instagram.com/p/BZmBbIClSHn/',
#  'https://www.instagram.com/p/BZUVGT7F9nD/',
#  'https://www.instagram.com/p/BZB4ncsl3Pq/',
#  'https://www.instagram.com/p/BYojJLhn9-j/',
#  'https://www.instagram.com/p/BYTyfkxnllD/',
#  'https://www.instagram.com/p/BYB3krplZnP/',
#  'https://www.instagram.com/p/BX3eyrhFZif/',
#  'https://www.instagram.com/p/BXgXHz5FUyO/',
#  'https://www.instagram.com/p/BW8RwEDFQWO/',
#  'https://www.instagram.com/p/BWf1cpyl4Mb/',
#  'https://www.instagram.com/p/BWdDEAVF3TC/',
#  'https://www.instagram.com/p/BWYMamlFDto/',
#  'https://www.instagram.com/p/BWNtlpAl0my/',
#  'https://www.instagram.com/p/BWIOFwZlNRq/',
#  'https://www.instagram.com/p/BVzx1l_lPNF/',
#  'https://www.instagram.com/p/BVqBYOflvzg/',
#  'https://www.instagram.com/p/BVQVt_vFBa5/',
#  'https://www.instagram.com/p/BUxK0ejFr6B/',
#  'https://www.instagram.com/p/BUnXNdklTT7/',
#  'https://www.instagram.com/p/BUkluH2lual/',
#  'https://www.instagram.com/p/BUcyf_HlAve/',
#  'https://www.instagram.com/p/BUNIOG_FGP9/',
#  'https://www.instagram.com/p/BUKVme5lguB/',
#  'https://www.instagram.com/p/BTwwvOFl0dX/',
#  'https://www.instagram.com/p/BTRwpb7g81h/',
#  'https://www.instagram.com/p/BS4H6fHlPG7/',
#  'https://www.instagram.com/p/BSyFCNUAxsh/',
#  'https://www.instagram.com/p/BSuITYUAi_Q/',
#  'https://www.instagram.com/p/BSW_vgGg5LB/',
#  'https://www.instagram.com/p/BSNv1qeBKcP/',
#  'https://www.instagram.com/p/BSMOzMlgLUP/',
#  'https://www.instagram.com/p/BSHfYHfAeLu/',
#  'https://www.instagram.com/p/BRJgLySBKQv/',
#  'https://www.instagram.com/p/BQqUbD5g0j_/',
#  'https://www.instagram.com/p/BPDwrJ5B6a5/',
#  'https://www.instagram.com/p/BOqUwrch7wK/',
#  'https://www.instagram.com/p/BN7hubihpv5/',
#  'https://www.instagram.com/p/BNiHAVBBsrJ/',
#  'https://www.instagram.com/p/BNdmcoYBmfP/',
#  'https://www.instagram.com/p/BNM5rSYhrdZ/',
#  'https://www.instagram.com/p/BNAZfs9BpNV/',
#  'https://www.instagram.com/p/BMHdfgzh48B/',
#  'https://www.instagram.com/p/BLuGEkLh2nb/',
#  'https://www.instagram.com/p/BLWbaQfBEl6/',
#  'https://www.instagram.com/p/BKwGh1_hbkv/',
#  'https://www.instagram.com/p/BKl17Enh95Z/',
#  'https://www.instagram.com/p/BKbnukzBjgR/',
#  'https://www.instagram.com/p/BKAvjYABySJ/',
#  'https://www.instagram.com/p/BJ8mhQ_Bedo/',
#  'https://www.instagram.com/p/BJ3t6BrBKR5/',
#  'https://www.instagram.com/p/BJ25wCKB3Ri/',
#  'https://www.instagram.com/p/BJx08GXBU81/',
#  'https://www.instagram.com/p/BJqoNe3h51b/',
#  'https://www.instagram.com/p/BJdjemdBpv0/',
#  'https://www.instagram.com/p/BJbIvfEBFjQ/',
#  'https://www.instagram.com/p/BJVKDoVByUP/',
#  'https://www.instagram.com/p/BJSghO7hx9_/',
#  'https://www.instagram.com/p/BJOAabnBHg9/',
#  'https://www.instagram.com/p/BJIeYZvBIeP/',
#  'https://www.instagram.com/p/BJGkPLThhnj/',
#  'https://www.instagram.com/p/BI-xRGbhYzN/',
#  'https://www.instagram.com/p/BI966L6BsZA/',
#  'https://www.instagram.com/p/BI3KglwhT29/',
#  'https://www.instagram.com/p/BI0pnDuBMYP/',
#  'https://www.instagram.com/p/BIsrX3LBq-x/',
#  'https://www.instagram.com/p/BImmrb-Bc9D/',
#  'https://www.instagram.com/p/BIAuv-1B4NS/',
#  'https://www.instagram.com/p/BHubvmcB4Ck/',
#  'https://www.instagram.com/p/BHnMZE4hGPo/',
#  'https://www.instagram.com/p/BHhcb3kBc-p/',
#  'https://www.instagram.com/p/BHXGGTNhfTy/',
#  'https://www.instagram.com/p/BHNh0K8hD_Q/',
#  'https://www.instagram.com/p/BHJ924zBUy8/',
#  'https://www.instagram.com/p/BHCPqCzhLRl/',
#  'https://www.instagram.com/p/BG_1xGGjbtn/',
#  'https://www.instagram.com/p/BGrLkc8jbhE/',
#  'https://www.instagram.com/p/BGplE87Dbur/',
#  'https://www.instagram.com/p/BGh_Xdqjbsu/',
#  'https://www.instagram.com/p/BGhNMn7DbkA/',
#  'https://www.instagram.com/p/BGRLIeKjbrj/',
#  'https://www.instagram.com/p/BF_lSF9jbmJ/',
#  'https://www.instagram.com/p/BFhNJXmjbp6/',
#  'https://www.instagram.com/p/BFeqDc4DbjX/',
#  'https://www.instagram.com/p/BFZzeaqjbo9/',
#  'https://www.instagram.com/p/BFX1XkFjbus/',
#  'https://www.instagram.com/p/BFOj27ZjbqY/',
#  'https://www.instagram.com/p/BFMPArwjbki/',
#  'https://www.instagram.com/p/BFG5LkpDbrR/',
#  'https://www.instagram.com/p/BFFGYw0DblH/',
#  'https://www.instagram.com/p/BE_SbUQDbhb/',
#  'https://www.instagram.com/p/BE-iesqDbox/',
#  'https://www.instagram.com/p/BE37SwsDbr6/',
#  'https://www.instagram.com/p/BEourrnDbnf/',
#  'https://www.instagram.com/p/BEmVaEgDbkv/',
#  'https://www.instagram.com/p/BEYqI8rjbjj/',
#  'https://www.instagram.com/p/BEWpDHxDbpj/',
#  'https://www.instagram.com/p/BEGsepiDbv2/',
#  'https://www.instagram.com/p/BEEtj7Ojbm4/',
#  'https://www.instagram.com/p/BD3HGRMDbrs/',
#  'https://www.instagram.com/p/BDyyYTBDbgB/',
#  'https://www.instagram.com/p/BDyjW3BDbhX/',
#  'https://www.instagram.com/p/BDlhc3UDblt/',
#  'https://www.instagram.com/p/BDjAPfvjbgb/',
#  'https://www.instagram.com/p/BDiQNuKjbuc/',
#  'https://www.instagram.com/p/BDfzgMejbjg/',
#  'https://www.instagram.com/p/BDdv-X6Dbua/',
#  'https://www.instagram.com/p/BDUJq8zjbow/',
#  'https://www.instagram.com/p/BDO8_4HDbp-/',
#  'https://www.instagram.com/p/BDBxLNkjblU/',
#  'https://www.instagram.com/p/BC4-WP5jbpn/',
#  'https://www.instagram.com/p/BCfzxVmDbon/',
#  'https://www.instagram.com/p/BCPwL61Dbs8/',
#  'https://www.instagram.com/p/BBvjSf1Dbmj/',
#  'https://www.instagram.com/p/BBqQBDbDbiZ/',
#  'https://www.instagram.com/p/BBfqyCvDbkR/',
#  'https://www.instagram.com/p/BBLqi5NjboC/',
#  'https://www.instagram.com/p/BA7RhWgDbt-/',
#  'https://www.instagram.com/p/BAjU7cwjbtY/',
#  'https://www.instagram.com/p/BAX-Njzjbge/',
#  'https://www.instagram.com/p/BAUg3ILjblr/',
#  'https://www.instagram.com/p/BAIdFqDjbkL/',
#  'https://www.instagram.com/p/BAIX_ibjboW/',
#  'https://www.instagram.com/p/BADFSY2Dbv-/',
#  'https://www.instagram.com/p/_rVKGtjbl1/',
#  'https://www.instagram.com/p/_kGMTYDbtq/',
#  'https://www.instagram.com/p/_kEvn9DbqM/',
#  'https://www.instagram.com/p/_XP8zsjbkN/',
#  'https://www.instagram.com/p/-56jhTDbi8/',
#  'https://www.instagram.com/p/-ZTDBfDbpE/',
#  'https://www.instagram.com/p/-XdqehDbqp/',
#  'https://www.instagram.com/p/-U2OFHDbie/',
#  'https://www.instagram.com/p/-ROt0SjbuR/',
#  'https://www.instagram.com/p/-HXXsSjbh9/',
#  'https://www.instagram.com/p/9yZRfTDbrU/',
#  'https://www.instagram.com/p/9wRytSDbv4/',
#  'https://www.instagram.com/p/9trkXwDbjW/',
#  'https://www.instagram.com/p/8qc3Lejblt/',
#  'https://www.instagram.com/p/8oiVfODbs0/',
#  'https://www.instagram.com/p/8go36rDbq6/',
#  'https://www.instagram.com/p/8QtSFtjbn7/',
#  'https://www.instagram.com/p/71OVCljbuK/',
#  'https://www.instagram.com/p/7xNb51DbqV/',
#  'https://www.instagram.com/p/7jR239DbuF/',
#  'https://www.instagram.com/p/7VO-mXjblL/',
#  'https://www.instagram.com/p/7VGxlOjbmu/',
#  'https://www.instagram.com/p/6iGK4pDboH/',
#  'https://www.instagram.com/p/6SleIWjbiV/',
#  'https://www.instagram.com/p/6NIlZQDbg2/',
#  'https://www.instagram.com/p/53RXNWjbrJ/',
#  'https://www.instagram.com/p/4jR6_Mjbpp/',
#  'https://www.instagram.com/p/4O3wqojbmE/',
#  'https://www.instagram.com/p/4Ee7zhjbm4/',
#  'https://www.instagram.com/p/311hhNDbm9/',
#  'https://www.instagram.com/p/3YqX39Dbkt/',
#  'https://www.instagram.com/p/3WQj4Ejbrt/',
#  'https://www.instagram.com/p/3Tavx0Dbsl/',
#  'https://www.instagram.com/p/2gMakxDbls/',
#  'https://www.instagram.com/p/2T9XcNDblK/',
#  'https://www.instagram.com/p/16LFdIDbjM/',
#  'https://www.instagram.com/p/1q3ng4DbsX/',
#  'https://www.instagram.com/p/1OQWjxDbiz/',
#  'https://www.instagram.com/p/zk4TNDDbho/',
#  'https://www.instagram.com/p/yubfgLjbir/',
#  'https://www.instagram.com/p/ypmW2Ojbvw/',
#  'https://www.instagram.com/p/x4yjf0Dbjt/',
#  'https://www.instagram.com/p/w9MM7wjbn-/',
#  'https://www.instagram.com/p/sxusFjDbhF/',
#  'https://www.instagram.com/p/spek5-jbkT/',
#  'https://www.instagram.com/p/smWuCUDbuz/',
#  'https://www.instagram.com/p/sfse9hjbpS/',
#  'https://www.instagram.com/p/sdZhvljbnO/',
#  'https://www.instagram.com/p/sAZnJ8DbqD/',
#  'https://www.instagram.com/p/rpVnO2jblr/',
#  'https://www.instagram.com/p/rnEqVBDblO/',
#  'https://www.instagram.com/p/rm2xl6DbuT/',
#  'https://www.instagram.com/p/rmLoBNDbsD/',
#  'https://www.instagram.com/p/rmAICmDbv7/',
#  'https://www.instagram.com/p/rkuZoxjbpj/',
#  'https://www.instagram.com/p/rkqm9sjbic/',
#  'https://www.instagram.com/p/rknS2ADbrl/',
#  'https://www.instagram.com/p/rkTB2xDbp4/',
#  'https://www.instagram.com/p/rkCjWujbqb/',
#  'https://www.instagram.com/p/rjnEVuDbi4/',
#  'https://www.instagram.com/p/rg9RSsjbhk/',
#  'https://www.instagram.com/p/rSg2vYjbpX/',
#  'https://www.instagram.com/p/rC55z0jbpZ/',
#  'https://www.instagram.com/p/rC5B-hjbn8/',
#  'https://www.instagram.com/p/qfFefoDbsU/',
#  'https://www.instagram.com/p/qSNc2yjbht/',
#  'https://www.instagram.com/p/qOfrauDbu2/',
#  'https://www.instagram.com/p/qOSV9DjbkD/',
#  'https://www.instagram.com/p/qMB-XSDbqL/',
#  'https://www.instagram.com/p/qL-1ngjbnk/',
#  'https://www.instagram.com/p/qHBUhpjbnV/',
#  'https://www.instagram.com/p/qGi37Ijbkt/',
#  'https://www.instagram.com/p/qGfwOVDbgf/',
#  'https://www.instagram.com/p/qESlx8Dbl6/',
#  'https://www.instagram.com/p/p8YQVWDbtt/',
#  'https://www.instagram.com/p/p6AOO_jbtI/',
#  'https://www.instagram.com/p/p5v-TLDbup/',
#  'https://www.instagram.com/p/p4fbxeDbmN/',
#  'https://www.instagram.com/p/p4XsMVjboN/',
#  'https://www.instagram.com/p/p4OxGaDbog/',
#  'https://www.instagram.com/p/pTzFPrjbpp/',
#  'https://www.instagram.com/p/oHBYqAjbjh/',
#  'https://www.instagram.com/p/n-yLK7jblc/',
#  'https://www.instagram.com/p/n41nB1DbrI/',
#  'https://www.instagram.com/p/ntJH42jbhn/',
#  'https://www.instagram.com/p/nlSZJ1jbs3/',
#  'https://www.instagram.com/p/nOoFwkjbmm/',
#  'https://www.instagram.com/p/nDC-rojbnH/',
#  'https://www.instagram.com/p/ms-cHMjboI/',
#  'https://www.instagram.com/p/ms0O4ujbid/',
#  'https://www.instagram.com/p/mnUjKwDbiI/',
#  'https://www.instagram.com/p/milswDDbhf/',
#  'https://www.instagram.com/p/mXDbnrDbvB/',
#  'https://www.instagram.com/p/mI7BjCDbiM/',
#  'https://www.instagram.com/p/mI0l0hDbmR/',
#  'https://www.instagram.com/p/mAXARtjboi/',
#  'https://www.instagram.com/p/l-B_1Wjbif/',
#  'https://www.instagram.com/p/l67fDAjbjv/',
#  'https://www.instagram.com/p/lsl3NWjbmN/',
#  'https://www.instagram.com/p/lsk2C3jbkp/',
#  'https://www.instagram.com/p/lnl3-Gjbjw/',
#  'https://www.instagram.com/p/lndP8jDbkg/',
#  'https://www.instagram.com/p/lnMYfYjbjD/',
#  'https://www.instagram.com/p/lmShs0Dbgz/',
#  'https://www.instagram.com/p/lj_5aoDbsz/',
#  'https://www.instagram.com/p/liG7nHjbmX/',
#  'https://www.instagram.com/p/liEzGUjbjU/',
#  'https://www.instagram.com/p/lb_Egwjbms/',
#  'https://www.instagram.com/p/lXDJpGDbrn/',
#  'https://www.instagram.com/p/lVMZrTDbhJ/',
#  'https://www.instagram.com/p/lRuZWFjbqU/',
#  'https://www.instagram.com/p/lPsOIDDbt4/',
#  'https://www.instagram.com/p/lIS74njbow/',
#  'https://www.instagram.com/p/lFRcjdDbqR/',
#  'https://www.instagram.com/p/lBM5yYjbqU/',
#  'https://www.instagram.com/p/lAukGRDbkk/',
#  'https://www.instagram.com/p/lAfNNajbos/',
#  'https://www.instagram.com/p/k7oM6jjbgP/',
#  'https://www.instagram.com/p/k7l5dNDbtO/',
#  'https://www.instagram.com/p/k197TGDbsQ/',
#  'https://www.instagram.com/p/ksK7I9DbmJ/',
#  'https://www.instagram.com/p/koqdbCDbmd/',
#  'https://www.instagram.com/p/kb_A5RjbhZ/',
#  'https://www.instagram.com/p/kUioKBDbm6/',
#  'https://www.instagram.com/p/kIjKv5jbt8/',
#  'https://www.instagram.com/p/kIh1RfDbr-/',
#  'https://www.instagram.com/p/kHM7GcjbkJ/',
#  'https://www.instagram.com/p/j6TsY5DbgY/',
#  'https://www.instagram.com/p/jmPAeHjbly/',
#  'https://www.instagram.com/p/jRGUGzjbsM/']

# %%
len(posts_url)
# 23
# Out:
# 301

# %%
##

# %%
listona2
listona_zord = list(dict.fromkeys(listona2))
post_url = [ x for x in listona_zord if "https://www.instagram.com/p/" in x ]

# %% [markdown]
# ### Coletando Informações do Post

# %%
content = driver.page_source
soup = BeautifulSoup(content)

# %%
def info_post():
    
    global texto_post
    global data_post
    global contagem_reacoes
    #global autor_post_id
    global tipo_post_video
    global tipo_post_photo
    global time_post
    global time_of_post2
    global data_post_real
    global data 
    
    content = driver.page_source
    soup = BeautifulSoup(content)
    
    ######### DATA POST
    data_post = []
    
    data = driver.find_element_by_tag_name('time')
    data_post_real= data.get_attribute("datetime") 
    
    try:
        for i in soup.findAll('time'):
                if i.has_attr('datetime'):
                    data_post.append(i['datetime'])
        time_post = data_post[0]
    except:
        time_post = ["NaN"]
    
   # texto_post2 = []
    #time_of_post2 = driver.find_element_by_xpath('//a/time').get_attribute("datetime")
    

    texto_post = []
    try:
        for i in driver.find_elements_by_xpath("//li/div/div/div/span"):
            texto_post.append(i.text)
        texto_post = texto_post[0]    
                #Get the first element
    except:
        pass 
    
    if texto_post == []:
        texto_post = ["NaN"]  
        
    
     ################
        
#    name_pattern = re.compile(r'webelement', flags = re.M)
#    tipo_post_video = len(name_pattern.findall(str(driver.find_element_by_tag_name('video')))) ##ok
    
    
   # name_pattern = re.compile(r'webelement', flags = re.M)
   # tipo_post_photo = len(name_pattern.findall(str(driver.find_element_by_tag_name('img'))))

#### Class to multi photos: vi798

# %%
info_post()
print(time_post)
print(texto_post)
#tipo_post_video
print(data_post_real)
# Out:
# 2020-02-14T19:45:23.000Z
# Two loves ❤️💚
# 2020-02-14T19:45:23.000Z

# %%
# ## FUNCIONA DO LADO DE FORA
# name_pattern = re.compile(r'webelement', flags = re.M)
# tipo_post_photo = len(name_pattern.findall(str(driver.find_element_by_tag_name('img'))))
# #tipo_post_photo

# tipo_post_video = len(name_pattern.findall(str(driver.find_element_by_tag_name('video'))))
# tipo_post_video


# ## Lista de itens pra ver se tem o Video
# # Class Ckrof
# # Class _9AhH0
# #eLAPa RzuR0
# # ZyFrc
# # tR2pe ##
# # rQDP3
# # pR7Pc

# %%
# links = driver.find_elements_by_xpath("//div[@class ='eLAPa kPFhm']")  #

# %%
#links = driver.find_elements_by_class_name('ZyFrc')
# links = driver.find_elements_by_xpath("//div[@class ='rQDP3']") 
# len(links) 

# content = driver.page_source
# soup = BeautifulSoup(content)
# texto_post = []
# #_6lAjh 

# for texto_post_ in driver.find_elements_by_tag_name('span'):
#                 texto_post.append(texto_post_.text)        
# texto_post

# %%
# .text.replace('<h3 class="_6lAjh"><div class="Igw0E IwRSH eGOV_ _4EzTm ItkAi"><span class="Jv7Aj mArmR MqpiF"><a class="sqdOP yWX7d _8A5w5 ZIAjV" href="/joao.carmo.5283/" tabindex="0">'," ").replace("\n"," ").strip()
#     name1=a.find('span', attrs={'class':''}).text

# %% [markdown]
# ### Coletando Informações dos Comentários

# %% [markdown]
# Revisar:
# - Limpeza da variável "Likes"
# - Status se está pegando todos os comentários

# %%
def scrap_comments():

    global comments2 #ok
    global comment_id2
    global autor2 #ok
    global like_comentario2
    global hora2 #ok
    global autor_id2
    global n_comments2
    #global n_respostas2
    global comment_url2
    global link_perfil2 
    global time_post
    global time_of_post
            
    comentario = driver.find_elements_by_css_selector('.C4VMK span')
    autor_comentario = driver.find_elements_by_class_name('_6lAjh')
    container = driver.find_elements_by_class_name('C4VMK')
    #time_post Está ali embaixo
    #likes_post
    links = driver.find_elements_by_class_name('_6lAjh ')
    
    
    autor = []
    comentarios = []
    time = []       
    horario_post2 = []
    link_perfil= []
    
    ##AUTOR
#     for autor0 in autor_comentario:
#         autor.append(autor0.text)
    
    ##COMENTÁRIO
    for i in comentario:
        comentarios.append(i.text) 
    
    coments = comentarios[1::2]  
   #print(comments)
    autor = comentarios[0::2]
   #print(autor)
    
    ##HORA COMENTÁRIO
    content = driver.page_source
    soup = BeautifulSoup(content)
    
    for i in soup.findAll('time'):
        if i.has_attr('datetime'):
            time.append(i['datetime'])
    time_post = time[1:]
    
    #HORA POST
    #horario_post = time[0] ### Colocar depois
    
    ##LIKES_COMENTÁRIO
    containerzaum = []
    like_comentario = []
    
    try:
        for i in container:
            containerzaum.append(i.text)

        containerzaum[0] = "XX--POST--XX"
        containerzaum

        for cont in containerzaum:
                like_comentario.append(cont[-12:])
    except:
            like_comentario = ["NaN"]
        

    
    for i in links:
        link_perfil.append(i.find_element_by_css_selector('a').get_attribute('href'))    
    
    time_of_post = driver.find_element_by_xpath('//a/time').get_attribute("datetime")

    
    autor2 += autor 
    comments2 += coments
    hora2 += time_post
    like_comentario2 += like_comentario
    link_perfil2 += link_perfil
    time_of_post

# %%
autor2 = []
comments2 = []
hora2 = []
like_comentario2 = []
horario_post2 = []
link_perfil2 = []


scrap_comments()


print(autor2) # 3
print(comments2)  # 3
print(hora2)  # 3
print(like_comentario2)  # 3
print(len(like_comentario2))
#horario_post2 NOT DONE
#print(link_perfil2)
# Out:
# ['tiagopires98', 'cristianacorreia98', 'inesirsaraiva']
# ['Loading 👣💬⏳', '💕💕💕', 'Lindoooos']
# ['2020-06-19T11:34:50.000Z', '2020-06-19T13:43:57.000Z', '2020-06-19T11:31:13.000Z']
# ['XX--POST--XX', 'w1 likeReply', '2 likesReply']
# 3

# %%
#Method1
# likes = driver.find_elements_by_xpath("//button[@class ='FH9sR']")
# like = []
# for i in likes:
#         like.append(i.text)
# like        

# #Method 2
# likes_comentario = driver.find_elements_by_class_name('FH9sR')
# like =[]
# for i in likes_comentario:
#         like.append(i.text)
# like

# #Method 3
# likes = []
# likes = [i.split('\n', 1)[1] for i in containerzaum]
# likes

# %% [markdown]
# # Função dentro de uma lista

# %%
from time import time

# %%
from time import time
start_time = time()

post_data = OrderedDict()

post_data['Categoria'] = []
post_data['Empresa'] = []
post_data['post_author_url'] = []
post_data['n'] = []
post_data['Empresa'] = []
post_data['post_author_url'] = []
post_data['n'] = []
post_data['URL_Post'] = []
post_data['Texto_Post'] = []
post_data['Data_Post'] = []
post_data['Partilhas'] = []
post_data['Tipo_post_video'] = []
post_data['Tipo_post_foto'] = []
post_data['Tipo_post_evento'] = []
post_data['Tipo_post_link'] = []
post_data['all'] = []
post_data['Likes_Comentario'] = []
post_data['Autor'] = []
post_data['Autor_id'] = []
post_data['Comentario']  = []
post_data['Comentario_id'] = []
post_data['Data_Comentario'] = []
post_data['N_respostas'] = []
post_data['Tempo_recolha'] = []
#post_data['Autor_Post_ID'] = []

# %%
post_data
# Out:
# OrderedDict([('Categoria', []),
#              ('Empresa', []),
#              ('post_author_url', []),
#              ('n', []),
#              ('URL_Post', []),
#              ('Texto_Post', []),
#              ('Data_Post', []),
#              ('Partilhas', []),
#              ('Tipo_post_video', []),
#              ('Tipo_post_foto', []),
#              ('Tipo_post_evento', []),
#              ('Tipo_post_link', []),
#              ('all', []),
#              ('Likes_Comentario', []),
#              ('Autor', []),
#              ('Autor_id', []),
#              ('Comentario', []),
#              ('Comentario_id', []),
#              ('Data_Comentario', []),
#              ('N_respostas', []),
#              ('Tempo_recolha', [])])

# %% [markdown]
# ### Get the URL Posts

# %%
def get_link():
    elements = driver.find_elements_by_xpath("//article/div/div/div/div/a[@href]")
    posts_url = []


    for elem in elements:
        urls = elem.get_attribute("href")
        if "p" in urls.split("/"):
            posts_url.append(urls)
    print(posts_url)

# %%
get_link()
# Out:
# ['https://www.instagram.com/p/CJMNf2hhbC3/', 'https://www.instagram.com/p/CFkz0gJhL4a/', 'https://www.instagram.com/p/CDgFnmOBZ3d/', 'https://www.instagram.com/p/CCCXjoGh_-B/', 'https://www.instagram.com/p/CB_iFHRBpBM/', 'https://www.instagram.com/p/CBnXV9-BoCL/', 'https://www.instagram.com/p/B-Cy6V5BHdQ/', 'https://www.instagram.com/p/B9u6P9FhojH/', 'https://www.instagram.com/p/B9kAcgAB2U1/', 'https://www.instagram.com/p/B8jzvIbhXrd/', 'https://www.instagram.com/p/B8gJYX3hZOZ/', 'https://www.instagram.com/p/B8ek78khRMd/', 'https://www.instagram.com/p/B6h_CWhhKrH/', 'https://www.instagram.com/p/B5ydqOnBrI2/', 'https://www.instagram.com/p/B5TSvTPhdT3/', 'https://www.instagram.com/p/B2XHOfvh-NX/', 'https://www.instagram.com/p/B1VyXJQBpy_/', 'https://www.instagram.com/p/B1RcZKoBGcv/', 'https://www.instagram.com/p/B0y1DJhB1JI/', 'https://www.instagram.com/p/B0HQtxoBirG/', 'https://www.instagram.com/p/BzyTUR3hqwT/', 'https://www.instagram.com/p/BztfG4WBD2Q/', 'https://www.instagram.com/p/ByQRpgthbao/', 'https://www.instagram.com/p/Bu4jvdchUkE/', 'https://www.instagram.com/p/Bt3wi_ZBXCi/', 'https://www.instagram.com/p/BtCWUGxhDkd/', 'https://www.instagram.com/p/Brgf1Ifhyf7/', 'https://www.instagram.com/p/BoCcSIrB8rX/', 'https://www.instagram.com/p/BnTlNqdhoQq/', 'https://www.instagram.com/p/BmorLswBgMQ/', 'https://www.instagram.com/p/BlTzV8eBnM9/', 'https://www.instagram.com/p/BlKy45fBtb4/', 'https://www.instagram.com/p/BkIrLkdBgXV/', 'https://www.instagram.com/p/BjXdL9wB4m4/', 'https://www.instagram.com/p/BjSmtMAhSSH/', 'https://www.instagram.com/p/BjDKMKPho9I/']

# %%
len(posts_url)
# Out:
# 301

# %% [markdown]
# ### Ativar a função

# %%
page_source = driver.page_source
profile_bs = BeautifulSoup(page_source, 'lxml')

# %%
base_url = "https://www.instagram.com/p"

# %%
ig["posts"][0:2]
# Out:
# 0    https://www.instagram.com/tiagopires98/?hl=en
# Name: posts, dtype: object

# %%
#Quantos Links deveria conter
elements = driver.find_element_by_class_name('g47SY ')
print("Deveria ter:" + elements.text + " Posts")
# Out:
# Deveria ter:301 Posts

# %%
def get_href():
        elements = driver.find_elements_by_xpath('//a[@href]')
        for elem in elements:
            urls = elem.get_attribute('href')
            if 'p' in urls.split('/'):
                links.append(urls)

# %% [markdown]
# ## Here comes the Magic

# %%
ig["posts"][0]
# Out:
# 'https://www.instagram.com/tiagopires98/?hl=en'

# %%
from tqdm.notebook import tqdm

# %%
if __name__ == "__main__":
    
    size_ = 0
    with tqdm(total=len(ig["posts"][0:])) as pbar:
        for company, lista_posts in enumerate(ig["posts"][0:], start=0):
            
            
            pbar.set_description(f'Tamanho da base: {size_} obs')
            pbar.update(1)   
            
            driver.get(lista_posts)
        
            scroll_down(driver)
            
            page_source = driver.page_source
            profile_bs = BeautifulSoup(page_source, 'lxml')

            company_ = ig["Empresa"][company]

            with tqdm(total=len(posts_url)) as pbar2:
                    for n, i in enumerate(posts_url, start=1):
                        pbar2.update(1)
                        pbar2.set_description(f'Posts da {company_}')

                        driver.get(i)
                        
                        info_post()                   
                        
                        
                        driver.get(i)
                       
                        autor = []
                        comentarios = []
                        time = []       
                        horario_post2 = []
                        link_perfil= []
                        
                        comments2 = []
                        autor2 = []
                        like_comentario2 = []
                        hora2 = []
                        comment_id2 = []
                        autor_id2 = []
                        comment_url2 = []
                        n_comments2 = []
                        
                        scrap_comments()

                        while len(driver.find_elements_by_xpath("//*[contains(@aria-label,'Load more comments')]")) == 1:

                            page_source = driver.page_source
                            profile_bs = BeautifulSoup(page_source, 'lxml')

                            comment_url_aux = []

                            elements = driver.find_elements_by_xpath("//article/div/div/div/div/a[@href]")
                            for elem in elements:
                                urls = elem.get_attribute("href")
                                if "p" in urls.split("/"):
                                    comment_url_aux.append(urls)

                            if comment_url_aux == []:
                                break

                            driver.get(comment_url_aux)

                            scrap_comments()

                            if len(comments2) == 0:
                                comments2, like_comentario2, autor2, hora2,like_comentario2 = ["NaN"], ["NaN"], ["NaN"], ["NaN"], ["NaN"]


                            comment_comment = comment_url2
                            if len(comment_url2) > 0:
                                for comment_count, aux in enumerate(comment_comment,start=0):
                                    comment_url2 = []
                                    driver.get(comment_comment[comment_count])
                                    scrap_comments()





                        post_data['Tempo_recolha'] = np.concatenate((post_data['Tempo_recolha'], np.tile(datetime.now(), len(comments2))))
                        post_data['Categoria'] = np.concatenate((post_data['Categoria'], np.tile(ig['Categoria'][company], len(comments2))))
                        post_data['Empresa'] = np.concatenate((post_data['Empresa'], np.tile(ig['Empresa'][company], len(comments2))))
                        post_data['post_author_url'] = np.concatenate((post_data['post_author_url'], np.tile(ig['posts'][company], len(comments2))))
                        post_data['n'] = np.concatenate((post_data['n'], np.tile(n, len(comments2))))
                        post_data['URL_Post'] = np.concatenate((post_data['URL_Post'], np.tile(i, len(comments2))))
                        post_data['Texto_Post'] = np.concatenate((post_data['Texto_Post'], np.tile(texto_post, len(comments2))))
                        post_data['Data_Post'] = np.concatenate((post_data['Data_Post'], np.tile(data_post_real, len(comments2))))
                  #      post_data['Partilhas'] = np.concatenate((post_data['Partilhas'], np.tile(partilhas, len(comments2))))
                        #post_data['Autor_Post_ID'] = np.concatenate((post_data['Autor_Post_ID'], np.tile(autor_post_id, len(comments2))))
                    #    post_data['Tipo_post_video'] = np.concatenate((post_data['Tipo_post_video'], np.tile(tipo_post_video, len(comments2))))
                   #     post_data['Tipo_post_foto'] = np.concatenate((post_data['Tipo_post_foto'], np.tile(tipo_post_foto, len(comments2))))
                    #    post_data['Tipo_post_evento'] = np.concatenate((post_data['Tipo_post_evento'], np.tile(tipo_post_evento, len(comments2))))
                    #    post_data['Tipo_post_link'] = np.concatenate((post_data['Tipo_post_link'], np.tile(tipo_post_link, len(comments2))))

                        size_ = len(post_data['URL_Post'])

                        post_data['Likes_Comentario'] = post_data['Likes_Comentario'] + like_comentario2
                        post_data['Autor'] = post_data['Autor'] + autor2
                     #   post_data['Autor_id'] = post_data['Autor_id'] + autor_id2
                        post_data['Comentario'] = post_data['Comentario'] + comments2
                     #   post_data['Comentario_id'] = post_data['Comentario_id'] + comment_id2
                        post_data['Data_Comentario'] = post_data['Data_Comentario'] + hora2
                     #   post_data['N_respostas'] = post_data['N_respostas'] + n_comments2

#     print("\n--- %s minutes ---" % ((time() - start_time)/60))
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=301.0), HTML(value='')))

# %%
post_data
# Out:
# OrderedDict([('Categoria',
#               array(['Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo'], dtype='<U32')),
#              ('Empresa',
#               array(['Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA'], dtype='<U32')),
#              ('post_author_url',
#               array(['https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
# ...
#                      datetime.datetime(2021, 3, 9, 16, 52, 53, 9340),
#                      datetime.datetime(2021, 3, 9, 16, 52, 53, 9340),
#                      datetime.datetime(2021, 3, 9, 16, 52, 53, 9340),
#                      datetime.datetime(2021, 3, 9, 16, 52, 53, 9340),
#                      datetime.datetime(2021, 3, 9, 16, 52, 53, 9340),
#                      datetime.datetime(2021, 3, 9, 16, 52, 53, 9340),
#                      datetime.datetime(2021, 3, 9, 16, 52, 53, 9340),
#                      datetime.datetime(2021, 3, 9, 16, 52, 53, 9340),
#                      datetime.datetime(2021, 3, 9, 16, 52, 58, 542798),
#                      datetime.datetime(2021, 3, 9, 16, 52, 58, 542798),
#                      datetime.datetime(2021, 3, 9, 16, 52, 58, 542798),
#                      datetime.datetime(2021, 3, 9, 16, 53, 4, 293017),
#                      datetime.datetime(2021, 3, 9, 16, 53, 4, 293017),
#                      datetime.datetime(2021, 3, 9, 16, 53, 4, 293017),
#                      datetime.datetime(2021, 3, 9, 16, 53, 4, 293017),
#                      datetime.datetime(2021, 3, 9, 16, 53, 8, 672158),
#                      datetime.datetime(2021, 3, 9, 16, 53, 8, 672158),
#                      datetime.datetime(2021, 3, 9, 16, 53, 8, 672158),
#                      datetime.datetime(2021, 3, 9, 16, 53, 8, 672158),
#                      datetime.datetime(2021, 3, 9, 16, 53, 15, 703133),
#                      datetime.datetime(2021, 3, 9, 16, 53, 15, 703133),
#                      datetime.datetime(2021, 3, 9, 16, 53, 15, 703133),
#                      datetime.datetime(2021, 3, 9, 16, 53, 15, 703133),
#                      datetime.datetime(2021, 3, 9, 16, 53, 15, 703133),
#                      datetime.datetime(2021, 3, 9, 16, 53, 20, 677728),
#                      datetime.datetime(2021, 3, 9, 16, 53, 20, 677728),
#                      datetime.datetime(2021, 3, 9, 16, 53, 24, 711880),
#                      datetime.datetime(2021, 3, 9, 16, 53, 27, 404534),
#                      datetime.datetime(2021, 3, 9, 16, 53, 33, 489432),
#                      datetime.datetime(2021, 3, 9, 16, 53, 33, 489432),
#                      datetime.datetime(2021, 3, 9, 16, 53, 38, 396652),
#                      datetime.datetime(2021, 3, 9, 16, 53, 38, 396652),
#                      datetime.datetime(2021, 3, 9, 16, 53, 42, 802943),
#                      datetime.datetime(2021, 3, 9, 16, 53, 42, 802943),
#                      datetime.datetime(2021, 3, 9, 16, 53, 42, 802943),
#                      datetime.datetime(2021, 3, 9, 16, 53, 48, 194364),
fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo', 'Fisioculturismo', 'Fisioculturismo',
#                      'Fisioculturismo'], dtype='<U32')),
#              ('Empresa',
#               array(['Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA',
#                      'Tiago CIA', 'Tiago CIA', 'Tiago CIA', 'Tiago CIA'], dtype='<U32')),
#              ('post_author_url',
#               array(['https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
#                      'https://www.instagram.com/tiagopires98/?hl=en',
# ...
#                      datetime.datetime(2021, 3, 9, 16, 52, 53, 9340),
#                      datetime.datetime(2021, 3, 9, 16, 52, 53, 9340),
#                      datetime.datetime(2021, 3, 9, 16, 52, 53, 9340),
#                      datetime.datetime(2021, 3, 9, 16, 52, 53, 9340),
#                      datetime.datetime(2021, 3, 9, 16, 52, 53, 9340),
#                      datetime.datetime(2021, 3, 9, 16, 52, 53, 9340),
#                      datetime.datetime(2021, 3, 9, 16, 52, 53, 9340),
#                      datetime.datetime(2021, 3, 9, 16, 52, 53, 9340),
#                      datetime.datetime(2021, 3, 9, 16, 52, 58, 542798),
#                      datetime.datetime(2021, 3, 9, 16, 52, 58, 542798),
#                      datetime.datetime(2021, 3, 9, 16, 52, 58, 542798),
#                      datetime.datetime(2021, 3, 9, 16, 53, 4, 293017),
#                      datetime.datetime(2021, 3, 9, 16, 53, 4, 293017),
#                      datetime.datetime(2021, 3, 9, 16, 53, 4, 293017),
#                      datetime.datetime(2021, 3, 9, 16, 53, 4, 293017),
#                      datetime.datetime(2021, 3, 9, 16, 53, 8, 672158),
#                      datetime.datetime(2021, 3, 9, 16, 53, 8, 672158),
#                      datetime.datetime(2021, 3, 9, 16, 53, 8, 672158),
#                      datetime.datetime(2021, 3, 9, 16, 53, 8, 672158),
#                      datetime.datetime(2021, 3, 9, 16, 53, 15, 703133),
#                      datetime.datetime(2021, 3, 9, 16, 53, 15, 703133),
#                      datetime.datetime(2021, 3, 9, 16, 53, 15, 703133),
#                      datetime.datetime(2021, 3, 9, 16, 53, 15, 703133),
#                      datetime.datetime(2021, 3, 9, 16, 53, 15, 703133),
#                      datetime.datetime(2021, 3, 9, 16, 53, 20, 677728),
#                      datetime.datetime(2021, 3, 9, 16, 53, 20, 677728),
#                      datetime.datetime(2021, 3, 9, 16, 53, 24, 711880),
#                      datetime.datetime(2021, 3, 9, 16, 53, 27, 404534),
#                      datetime.datetime(2021, 3, 9, 16, 53, 33, 489432),
#                      datetime.datetime(2021, 3, 9, 16, 53, 33, 489432),
#                      datetime.datetime(2021, 3, 9, 16, 53, 38, 396652),
#                      datetime.datetime(2021, 3, 9, 16, 53, 38, 396652),
#                      datetime.datetime(2021, 3, 9, 16, 53, 42, 802943),
#                      datetime.datetime(2021, 3, 9, 16, 53, 42, 802943),
#                      datetime.datetime(2021, 3, 9, 16, 53, 42, 802943),
#                      datetime.datetime(2021, 3, 9, 16, 53, 48, 194364),
#                      datetime.datetime(2021, 3, 9, 16, 53, 48, 194364),
#                      datetime.datetime(2021, 3, 9, 16, 53, 48, 194364),
#                      datetime.datetime(2021, 3, 9, 16, 55, 28, 88605),
#                      datetime.datetime(2021, 3, 9, 16, 55, 31, 497173),
#                      datetime.datetime(2021, 3, 9, 16, 55, 31, 497173),
#                      datetime.datetime(2021, 3, 9, 16, 55, 35, 995524),
#                      datetime.datetime(2021, 3, 9, 16, 55, 40, 533536),
#                      datetime.datetime(2021, 3, 9, 16, 55, 45, 657638),
#                      datetime.datetime(2021, 3, 9, 16, 55, 49, 722429),
#                      datetime.datetime(2021, 3, 9, 16, 55, 56, 335106),
#                      datetime.datetime(2021, 3, 9, 16, 56, 0, 607786),
#                      datetime.datetime(2021, 3, 9, 16, 56, 0, 607786),
#                      datetime.datetime(2021, 3, 9, 16, 56, 4, 406841),
#                      datetime.datetime(2021, 3, 9, 16, 56, 8, 717936),
#                      datetime.datetime(2021, 3, 9, 16, 56, 8, 717936),
#                      datetime.datetime(2021, 3, 9, 16, 56, 8, 717936),
#                      datetime.datetime(2021, 3, 9, 16, 56, 8, 717936),
#                      datetime.datetime(2021, 3, 9, 16, 56, 12, 93934),
#                      datetime.datetime(2021, 3, 9, 16, 56, 12, 93934),
#                      datetime.datetime(2021, 3, 9, 16, 56, 16, 415684),
#                      datetime.datetime(2021, 3, 9, 16, 56, 20, 728026),
#                      datetime.datetime(2021, 3, 9, 16, 56, 23, 863183),
#                      datetime.datetime(2021, 3, 9, 16, 56, 23, 863183),
#                      datetime.datetime(2021, 3, 9, 16, 56, 26, 494917),
#                      datetime.datetime(2021, 3, 9, 16, 56, 32, 439065),
#                      datetime.datetime(2021, 3, 9, 16, 56, 36, 509109),
#                      datetime.datetime(2021, 3, 9, 16, 56, 40, 524706),
#                      datetime.datetime(2021, 3, 9, 16, 56, 40, 524706),
#                      datetime.datetime(2021, 3, 9, 16, 56, 40, 524706),
#                      datetime.datetime(2021, 3, 9, 16, 56, 44, 789258),
#                      datetime.datetime(2021, 3, 9, 16, 56, 44, 789258),
#                      datetime.datetime(2021, 3, 9, 16, 56, 48, 773202),
#                      datetime.datetime(2021, 3, 9, 16, 56, 54, 698759),
#                      datetime.datetime(2021, 3, 9, 16, 56, 54, 698759),
#                      datetime.datetime(2021, 3, 9, 16, 56, 54, 698759),
#                      datetime.datetime(2021, 3, 9, 16, 56, 54, 698759),
#                      datetime.datetime(2021, 3, 9, 16, 56, 54, 698759),
#                      datetime.datetime(2021, 3, 9, 16, 56, 54, 698759),
#                      datetime.datetime(2021, 3, 9, 16, 56, 54, 698759),
#                      datetime.datetime(2021, 3, 9, 16, 56, 54, 698759),
#                      datetime.datetime(2021, 3, 9, 16, 56, 54, 698759),
#                      datetime.datetime(2021, 3, 9, 16, 56, 54, 698759),
#                      datetime.datetime(2021, 3, 9, 16, 56, 54, 698759),
#                      datetime.datetime(2021, 3, 9, 16, 56, 54, 698759),
#                      datetime.datetime(2021, 3, 9, 16, 56, 54, 698759),
#                      datetime.datetime(2021, 3, 9, 16, 56, 57, 957746),
#                      datetime.datetime(2021, 3, 9, 16, 57, 1, 82514),
#                      datetime.datetime(2021, 3, 9, 16, 57, 4, 317018),
#                      datetime.datetime(2021, 3, 9, 16, 59, 4, 675697),
#                      datetime.datetime(2021, 3, 9, 16, 59, 8, 497555),
#                      datetime.datetime(2021, 3, 9, 16, 59, 11, 646642),
#                      datetime.datetime(2021, 3, 9, 16, 59, 11, 646642),
#                      datetime.datetime(2021, 3, 9, 16, 59, 16, 985853),
#                      datetime.datetime(2021, 3, 9, 16, 59, 22, 554442),
#                      datetime.datetime(2021, 3, 9, 16, 59, 28, 307869),
#                      datetime.datetime(2021, 3, 9, 16, 59, 35, 52840),
#                      datetime.datetime(2021, 3, 9, 16, 59, 40, 394737),
#                      datetime.datetime(2021, 3, 9, 16, 59, 48, 705305),
#                      datetime.datetime(2021, 3, 9, 16, 59, 48, 705305),
#                      datetime.datetime(2021, 3, 9, 16, 59, 55, 500455),
#                      datetime.datetime(2021, 3, 9, 17, 0, 2, 395526),
#                      datetime.datetime(2021, 3, 9, 17, 0, 2, 395526),
#                      datetime.datetime(2021, 3, 9, 17, 0, 8, 316864),
#                      datetime.datetime(2021, 3, 9, 17, 0, 15, 344396),
#                      datetime.datetime(2021, 3, 9, 17, 0, 15, 344396),
#                      datetime.datetime(2021, 3, 9, 17, 0, 22, 103847),
#                      datetime.datetime(2021, 3, 9, 17, 0, 29, 151528),
#                      datetime.datetime(2021, 3, 9, 17, 0, 34, 672768),
#                      datetime.datetime(2021, 3, 9, 17, 0, 41, 382193),
#                      datetime.datetime(2021, 3, 9, 17, 0, 47, 677025),
#                      datetime.datetime(2021, 3, 9, 17, 0, 51, 940486),
#                      datetime.datetime(2021, 3, 9, 17, 0, 57, 506102),
#                      datetime.datetime(2021, 3, 9, 17, 1, 5, 788535),
#                      datetime.datetime(2021, 3, 9, 17, 1, 5, 788535),
#                      datetime.datetime(2021, 3, 9, 17, 1, 11, 563944),
#                      datetime.datetime(2021, 3, 9, 17, 1, 11, 563944),
#                      datetime.datetime(2021, 3, 9, 17, 1, 11, 563944),
#                      datetime.datetime(2021, 3, 9, 17, 1, 16, 180861),
#                      datetime.datetime(2021, 3, 9, 17, 1, 22, 736353),
#                      datetime.datetime(2021, 3, 9, 17, 1, 22, 736353),
#                      datetime.datetime(2021, 3, 9, 17, 1, 22, 736353),
#                      datetime.datetime(2021, 3, 9, 17, 1, 27, 306565),
#                      datetime.datetime(2021, 3, 9, 17, 1, 33, 498827),
#                      datetime.datetime(2021, 3, 9, 17, 1, 33, 498827),
#                      datetime.datetime(2021, 3, 9, 17, 1, 33, 498827),
#                      datetime.datetime(2021, 3, 9, 17, 1, 38, 557270),
#                      datetime.datetime(2021, 3, 9, 17, 1, 42, 530423),
#                      datetime.datetime(2021, 3, 9, 17, 1, 52, 84737),
#                      datetime.datetime(2021, 3, 9, 17, 1, 52, 84737),
#                      datetime.datetime(2021, 3, 9, 17, 1, 52, 84737),
#                      datetime.datetime(2021, 3, 9, 17, 1, 52, 84737),
#                      datetime.datetime(2021, 3, 9, 17, 1, 52, 84737),
#                      datetime.datetime(2021, 3, 9, 17, 1, 57, 744569),
#                      datetime.datetime(2021, 3, 9, 17, 2, 4, 8399),
#                      datetime.datetime(2021, 3, 9, 17, 2, 13, 808259),
#                      datetime.datetime(2021, 3, 9, 17, 2, 13, 808259)], dtype=object))])

# %% [markdown]
# ## Base Final

# %%
post_data2 = {'Data_recolha':post_data['Tempo_recolha'],
              'Categoria':post_data['Categoria'],
              'Empresa':post_data['Empresa'],
              'post_author_url':post_data['post_author_url'],
              #'Autor_Post_ID':post_data['Autor_Post_ID'],
              'n': post_data['n'],
              'URL_Post': post_data['URL_Post'],
              'Texto_Post' : post_data['Texto_Post'],
              'Data_Post' : post_data['Data_Post'] ,
            #  'Qtd_post_video':post_data['Tipo_post_video'], 
              #'Qtd_post_foto':post_data['Tipo_post_foto'], 
              'Likes_Comentario' : post_data['Likes_Comentario'],
              'Autor': post_data['Autor'], 
              'Comentario': post_data['Comentario'],
              'Data_Comentario': post_data['Data_Comentario'], 
              'Tempo_Recolha': post_data['Tempo_recolha']
             }

post_data3 = pd.DataFrame.from_dict(post_data2, orient='index')

# %%
post_data3
# Out:
#                                                                 0    \
# Data_recolha                             2021-03-09 16:40:44.147811
# Categoria                                           Fisioculturismo
# Empresa                                                   Tiago CIA
# post_author_url       https://www.instagram.com/tiagopires98/?hl=en
# n                                                                 1
# URL_Post                   https://www.instagram.com/p/CJMNf2hhbC3/
# Texto_Post        Falar de justiça, ou falta, dela é diminuto. A...
# Data_Post                                  2020-12-24T18:36:51.000Z
# Likes_Comentario                                       XX--POST--XX
# Autor                                                  tiagopires98
# Comentario        Falar de justiça, ou falta, dela é diminuto. A...
# Data_Comentario                            2020-12-24T23:19:07.000Z
# Tempo_Recolha                            2021-03-09 16:40:44.147811
#
#                                                                 1    \
# Data_recolha                             2021-03-09 16:40:44.147811
# Categoria                                           Fisioculturismo
# Empresa                                                   Tiago CIA
# post_author_url       https://www.instagram.com/tiagopires98/?hl=en
# n                                                                 1
# URL_Post                   https://www.instagram.com/p/CJMNf2hhbC3/
# Texto_Post        Falar de justiça, ou falta, dela é diminuto. A...
# Data_Post                                  2020-12-24T18:36:51.000Z
# Likes_Comentario                                     6\n💯\n10wReply
# Autor                                            19afonsoferreira06
# Comentario                                                        💯
# Data_Comentario                            2020-12-24T18:36:51.000Z
# Tempo_Recolha                            2021-03-09 16:40:44.147811
#
#                                                                 2    \
# Data_recolha                             2021-03-09 16:40:47.609275
# Categoria                                           Fisioculturismo
# Empresa                                                   Tiago CIA
# post_author_url       https://www.instagram.com/tiagopires98/?hl=en
# n                                                                 2
# URL_Post                   https://www.instagram.com/p/CFkz0gJhL4a/
# Texto_Post        "Para poder chegar aonde se quer, tudo depende...
# Data_Post                                  2020-09-25T21:47:55.000Z
# Likes_Comentario                                       XX--POST--XX
# Autor                                                  tiagopires98
# Comentario        "Para poder chegar aonde se quer, tudo depende...
# Data_Comentario                            2020-09-25T21:47:55.000Z
# Tempo_Recolha                            2021-03-09 16:40:47.609275
#
#                                                             3    \
# Data_recolha                         2021-03-09 16:40:53.516193
# Categoria                                       Fisioculturismo
# Empresa                                               Tiago CIA
# post_author_url   https://www.instagram.com/tiagopires98/?hl=en
# n                                                             3
# URL_Post               https://www.instagram.com/p/CDgFnmOBZ3d/
# Texto_Post              Visite o interior. A sério. É porreiro.
# Data_Post                              2020-08-05T08:44:27.000Z
# Likes_Comentario                                   XX--POST--XX
# Autor                                              tiagopires98
# Comentario              Visite o interior. A sério. É porreiro.
# Data_Comentario                        2020-08-05T11:25:41.000Z
# Tempo_Recolha                        2021-03-09 16:40:53.516193
#
#                                                             4    \
# Data_recolha                         2021-03-09 16:40:53.516193
# Categoria                                       Fisioculturismo
# Empresa                                               Tiago CIA
# post_author_url   https://www.instagram.com/tiagopires98/?hl=en
# n                                                             3
# URL_Post               https://www.instagram.com/p/CDgFnmOBZ3d/
# Texto_Post              Visite o interior. A sério. É porreiro.
# Data_Post                              2020-08-05T08:44:27.000Z
# Likes_Comentario                                   w1 likeReply
# Autor                                              edu.bcardoso
# Comentario                                             Amen! 🙏🏻
# Data_Comentario                        2020-08-05T12:07:38.000Z
# Tempo_Recolha                        2021-03-09 16:40:53.516193
#
#                                                             5    \
# Data_recolha                         2021-03-09 16:40:53.516193
# Categoria                                       Fisioculturismo
# Empresa                                               Tiago CIA
# post_author_url   https://www.instagram.com/tiagopires98/?hl=en
# n                                                             3
# URL_Post               https://www.instagram.com/p/CDgFnmOBZ3d/
# Texto_Post              Visite o interior. A sério. É porreiro.
# Data_Post                              2020-08-05T08:44:27.000Z
# Likes_Comentario                                   w1 likeReply
# Autor                                        cristianacorreia98
# Comentario                                          Jeitoso 😂❤️
# Data_Comentario                        2020-08-06T17:12:42.000Z
# Tempo_Recolha                        2021-03-09 16:40:53.516193
#
#                                                               6    \
# Data_recolha                           2021-03-09 16:40:53.516193
# Categoria                                         Fisioculturismo
# Empresa                                                 Tiago CIA
# post_author_url     https://www.instagram.com/tiagopires98/?hl=en
# n                                                               3
# URL_Post                 https://www.instagram.com/p/CDgFnmOBZ3d/
# Texto_Post                Visite o interior. A sério. É porreiro.
# Data_Post                                2020-08-05T08:44:27.000Z
# Likes_Comentario                                     w1 likeReply
# Autor                                                    raleixo0
# Comentario        Mensagem patrocinada pelo Turismo de Portugal 😂
# Data_Comentario                          2020-08-05T08:44:27.000Z
# Tempo_Recolha                          2021-03-09 16:40:53.516193
#
#                                                             7    \
# Data_recolha                         2021-03-09 16:41:02.016909
# Categoria                                       Fisioculturismo
# Empresa                                               Tiago CIA
# post_author_url   https://www.instagram.com/tiagopires98/?hl=en
# n                                                             4
# URL_Post               https://www.instagram.com/p/CCCXjoGh_-B/
# Texto_Post                                  O melhor de 2020 😁😜
# Data_Post                              2020-06-29T23:12:35.000Z
# Likes_Comentario                                   XX--POST--XX
# Autor                                              tiagopires98
# Comentario                                  O melhor de 2020 😁😜
# Data_Comentario                        2020-06-29T23:45:12.000Z
# Tempo_Recolha                        2021-03-09 16:41:02.016909
#
#                                                             8    \
# Data_recolha                         2021-03-09 16:41:02.016909
# Categoria                                       Fisioculturismo
# Empresa                                               Tiago CIA
# post_author_url   https://www.instagram.com/tiagopires98/?hl=en
# n                                                             4
# URL_Post               https://www.instagram.com/p/CCCXjoGh_-B/
# Texto_Post                                  O melhor de 2020 😁😜
# Data_Post                              2020-06-29T23:12:35.000Z
# Likes_Comentario                                   2 likesReply
# Autor                                           pedroasppereira
# Comentario                                 Eu não faço parte? 😢
# Data_Comentario                        2020-06-30T08:58:09.000Z
# Tempo_Recolha                        2021-03-09 16:41:02.016909
#
#                                                             9    ...  \
# Data_recolha                         2021-03-09 16:41:02.016909  ...
# Categoria                                       Fisioculturismo  ...
# Empresa                                               Tiago CIA  ...
# post_author_url   https://www.instagram.com/tiagopires98/?hl=en  ...
# n                                                             4  ...
# URL_Post               https://www.instagram.com/p/CCCXjoGh_-B/  ...
# Texto_Post                                  O melhor de 2020 😁😜  ...
# Data_Post                              2020-06-29T23:12:35.000Z  ...
# Likes_Comentario                                  u ?\n36wReply  ...
# Autor                                         pedrocoutodesousa  ...
# Comentario                                Onde é que eu estou ?  ...
# Data_Comentario                        2020-06-29T23:12:35.000Z  ...
# Tempo_Recolha                        2021-03-09 16:41:02.016909  ...
#
#                                                             804  \
# Data_recolha                         2021-03-09 17:01:42.530423
# Categoria                                       Fisioculturismo
# Empresa                                               Tiago CIA
# post_author_url   https://www.instagram.com/tiagopires98/?hl=en
# n                                                           297
# URL_Post                https://www.instagram.com/p/kIh1RfDbr-/
# Texto_Post                                    #ultima #pergunta
# Data_Post                              2014-02-07T23:26:46.000Z
# Likes_Comentario                                   XX--POST--XX
# Autor                                              tiagopires98
# Comentario                                    #ultima #pergunta
# Data_Comentario                        2014-02-07T23:26:46.000Z
# Tempo_Recolha                        2021-03-09 17:01:42.530423
#
#                                                             805  \
# Data_recolha                         2021-03-09 17:01:52.084737
# Categoria                                       Fisioculturismo
# Empresa                                               Tiago CIA
# post_author_url   https://www.instagram.com/tiagopires98/?hl=en
# n                                                           298
# URL_Post                https://www.instagram.com/p/kHM7GcjbkJ/
# Texto_Post                                      Varios graficos
# Data_Post                              2014-02-07T11:04:49.000Z
# Likes_Comentario                                   XX--POST--XX
# Autor                                              tiagopires98
# Comentario                                      Varios graficos
# Data_Comentario                        2014-02-07T11:06:52.000Z
# Tempo_Recolha                        2021-03-09 17:01:52.084737
#
#                                                             806  \
# Data_recolha                         2021-03-09 17:01:52.084737
# Categoria                                       Fisioculturismo
# Empresa                                               Tiago CIA
# post_author_url   https://www.instagram.com/tiagopires98/?hl=en
# n                                                           298
# URL_Post                https://www.instagram.com/p/kHM7GcjbkJ/
# Texto_Post                                      Varios graficos
# Data_Post                              2014-02-07T11:04:49.000Z
# Likes_Comentario                                  os\n369wReply
# Autor                                              tiagopires98
# Comentario                                        Varios abusos
# Data_Comentario                        2014-02-07T13:20:08.000Z
# Tempo_Recolha                        2021-03-09 17:01:52.084737
#
#                                                             807  \
# Data_recolha                         2021-03-09 17:01:52.084737
# Categoria                                       Fisioculturismo
# Empresa                                               Tiago CIA
# post_author_url   https://www.instagram.com/tiagopires98/?hl=en
# n                                                           298
# URL_Post                https://www.instagram.com/p/kHM7GcjbkJ/
# Texto_Post                                      Varios graficos
# Data_Post                              2014-02-07T11:04:49.000Z
# Likes_Comentario                                  06\n369wReply
# Autor                                              tiagopires98
# Comentario                              Sabes @joao_pereira1906
# Data_Comentario                        2021-03-09T16:28:25.000Z
# Tempo_Recolha                        2021-03-09 17:01:52.084737
#
#                                                             808  \
# Data_recolha                         2021-03-09 17:01:52.084737
# Categoria                                       Fisioculturismo
# Empresa                                               Tiago CIA
# post_author_url   https://www.instagram.com/tiagopires98/?hl=en
# n                                                           298
# URL_Post                https://www.instagram.com/p/kHM7GcjbkJ/
# Texto_Post                                      Varios graficos
# Data_Post                              2014-02-07T11:04:49.000Z
# Likes_Comentario                                  ste\n33mReply
# Autor                                         gabrielravisantos
# Comentario                                                teste
# Data_Comentario                        2021-03-09T16:29:53.000Z
# Tempo_Recolha                        2021-03-09 17:01:52.084737
#
#                                                             809  \
# Data_recolha                         2021-03-09 17:01:52.084737
# Categoria                                       Fisioculturismo
# Empresa                                               Tiago CIA
# post_author_url   https://www.instagram.com/tiagopires98/?hl=en
# n                                                           298
# URL_Post                https://www.instagram.com/p/kHM7GcjbkJ/
# Texto_Post                                      Varios graficos
# Data_Post                              2014-02-07T11:04:49.000Z
# Likes_Comentario                                  e 2\n31mReply
# Autor                                         gabrielravisantos
# Comentario                                              Teste 2
# Data_Comentario                        2014-02-07T11:04:49.000Z
# Tempo_Recolha                        2021-03-09 17:01:52.084737
#
#                                                             810  \
# Data_recolha                         2021-03-09 17:01:57.744569
# Categoria                                       Fisioculturismo
# Empresa                                               Tiago CIA
# post_author_url   https://www.instagram.com/tiagopires98/?hl=en
# n                                                           299
# URL_Post                https://www.instagram.com/p/j6TsY5DbgY/
# Texto_Post         #domingo #nada #pa #fazer #bonecos #bom #dia
# Data_Post                              2014-02-02T10:53:51.000Z
# Likes_Comentario                                   XX--POST--XX
# Autor                                              tiagopires98
# Comentario         #domingo #nada #pa #fazer #bonecos #bom #dia
# Data_Comentario                        2014-02-02T10:53:51.000Z
# Tempo_Recolha                        2021-03-09 17:01:57.744569
#
#                                                             811  \
# Data_recolha                         2021-03-09 17:02:04.008399
# Categoria                                       Fisioculturismo
# Empresa                                               Tiago CIA
# post_author_url   https://www.instagram.com/tiagopires98/?hl=en
# n                                                           300
# URL_Post                https://www.instagram.com/p/jmPAeHjbly/
# Texto_Post            #boa #tarde #pro #evolution #soccer #2014
# Data_Post                              2014-01-25T15:48:05.000Z
# Likes_Comentario                                   XX--POST--XX
# Autor                                              tiagopires98
# Comentario            #boa #tarde #pro #evolution #soccer #2014
# Data_Comentario                        2014-01-25T15:48:05.000Z
# Tempo_Recolha                        2021-03-09 17:02:04.008399
#
#                                                             812  \
# Data_recolha                         2021-03-09 17:02:13.808259
# Categoria                                       Fisioculturismo
# Empresa                                               Tiago CIA
# post_author_url   https://www.instagram.com/tiagopires98/?hl=en
# n                                                           301
# URL_Post                https://www.instagram.com/p/jRGUGzjbsM/
# Texto_Post          #somos #fixes @sarateixeira07 @tiagopires98
# Data_Post                              2014-01-17T14:20:19.000Z
# Likes_Comentario                                   XX--POST--XX
# Autor                                               inespferrao
# Comentario          #somos #fixes @sarateixeira07 @tiagopires98
# Data_Comentario                        2018-10-25T12:31:24.000Z
# Tempo_Recolha                        2021-03-09 17:02:13.808259
#
#                                                             813
# Data_recolha                         2021-03-09 17:02:13.808259
# Categoria                                       Fisioculturismo
# Empresa                                               Tiago CIA
# post_author_url   https://www.instagram.com/tiagopires98/?hl=en
# n                                                           301
# URL_Post                https://www.instagram.com/p/jRGUGzjbsM/
# Texto_Post          #somos #fixes @sarateixeira07 @tiagopires98
# Data_Post                              2014-01-17T14:20:19.000Z
# Likes_Comentario                                  os\n123wReply
# Autor                                                  raleixo0
# Comentario                                   Tens lábios lindos
# Data_Comentario                        2014-01-17T10:48:05.000Z
# Tempo_Recolha                        2021-03-09 17:02:13.808259
#
# [13 rows x 814 columns]

# %%
base = post_data3.transpose()

# sticker = base['Autor'] == base['Comentario']
# base.loc[sticker,'Comentario'] = ''

# fotos = base.loc[(base.Qtd_post_video==0) & (base.Qtd_post_foto==0) & (base.Qtd_post_evento==0) & (base.Qtd_post_link==0),'URL_Post'].str.contains(pat = 'photo')
# base.loc[fotos.index,'Qtd_post_foto'] = 1

# videos = base.loc[(base.Qtd_post_video==0) & (base.Qtd_post_foto==0) & (base.Qtd_post_evento==0) & (base.Qtd_post_link==0),'URL_Post'].str.contains(pat = 'video')
# base.loc[videos.index,'Qtd_post_video'] = 1

# base

# %%
base.head(5)
# Out:
#                 Data_recolha        Categoria    Empresa  \
# 0 2021-03-09 16:40:44.147811  Fisioculturismo  Tiago CIA
# 1 2021-03-09 16:40:44.147811  Fisioculturismo  Tiago CIA
# 2 2021-03-09 16:40:47.609275  Fisioculturismo  Tiago CIA
# 3 2021-03-09 16:40:53.516193  Fisioculturismo  Tiago CIA
# 4 2021-03-09 16:40:53.516193  Fisioculturismo  Tiago CIA
#
#                                  post_author_url  n  \
# 0  https://www.instagram.com/tiagopires98/?hl=en  1
# 1  https://www.instagram.com/tiagopires98/?hl=en  1
# 2  https://www.instagram.com/tiagopires98/?hl=en  2
# 3  https://www.instagram.com/tiagopires98/?hl=en  3
# 4  https://www.instagram.com/tiagopires98/?hl=en  3
#
#                                    URL_Post  \
# 0  https://www.instagram.com/p/CJMNf2hhbC3/
# 1  https://www.instagram.com/p/CJMNf2hhbC3/
# 2  https://www.instagram.com/p/CFkz0gJhL4a/
# 3  https://www.instagram.com/p/CDgFnmOBZ3d/
# 4  https://www.instagram.com/p/CDgFnmOBZ3d/
#
#                                           Texto_Post  \
# 0  Falar de justiça, ou falta, dela é diminuto. A...
# 1  Falar de justiça, ou falta, dela é diminuto. A...
# 2  "Para poder chegar aonde se quer, tudo depende...
# 3            Visite o interior. A sério. É porreiro.
# 4            Visite o interior. A sério. É porreiro.
#
#                   Data_Post Likes_Comentario               Autor  \
# 0  2020-12-24T18:36:51.000Z     XX--POST--XX        tiagopires98
# 1  2020-12-24T18:36:51.000Z   6\n💯\n10wReply  19afonsoferreira06
# 2  2020-09-25T21:47:55.000Z     XX--POST--XX        tiagopires98
# 3  2020-08-05T08:44:27.000Z     XX--POST--XX        tiagopires98
# 4  2020-08-05T08:44:27.000Z     w1 likeReply        edu.bcardoso
#
#                                           Comentario  \
# 0  Falar de justiça, ou falta, dela é diminuto. A...
# 1                                                  💯
# 2  "Para poder chegar aonde se quer, tudo depende...
# 3            Visite o interior. A sério. É porreiro.
# 4                                           Amen! 🙏🏻
#
#             Data_Comentario              Tempo_Recolha
# 0  2020-12-24T23:19:07.000Z 2021-03-09 16:40:44.147811
# 1  2020-12-24T18:36:51.000Z 2021-03-09 16:40:44.147811
# 2  2020-09-25T21:47:55.000Z 2021-03-09 16:40:47.609275
# 3  2020-08-05T11:25:41.000Z 2021-03-09 16:40:53.516193
# 4  2020-08-05T12:07:38.000Z 2021-03-09 16:40:53.516193

# %%
base.Comentario.value_counts()
# Out:
# #road #to #alvalade                            3
# Uhuh que gatinho                               2
# Obg meus lindos ♥️dps fazemos a churrascada    2
# 5/10 comia mas n sei se repetia                2
# No meco                                        1
#                                               ..
# End of day ⚽👆😎☀ #quevenhaoverão                1
# claro ahah quem pode pode :) @tiagopires98     1
# lindo primo @tiagopires98                      1
# Parabéns a ti !!🎓🎓❤💚                           1
# Sempre cá, Titi 💚                              1
# Name: Comentario, Length: 809, dtype: int64

# %%
base.Data_Post.value_counts()
# Out:
# 2020-07-12T21:05:16.000Z    10
# 2020-04-23T19:45:34.000Z    10
# 2019-07-25T00:17:36.000Z     7
# 2019-08-19T17:16:32.000Z     6
# 2019-07-22T13:49:19.000Z     5
# 2019-07-22T18:19:48.000Z     5
# 2018-09-10T10:30:58.000Z     5
# 2019-07-20T04:00:37.000Z     5
# 2021-01-09T09:44:06.000Z     4
# 2019-08-16T00:04:47.000Z     4
# 2019-08-07T21:19:19.000Z     4
# 2019-08-23T19:15:19.000Z     4
# 2019-06-30T16:39:14.000Z     4
# 2018-07-30T23:05:17.000Z     4
# 2018-08-17T04:10:13.000Z     3
# 2018-08-10T16:43:45.000Z     3
# 2018-07-29T21:19:49.000Z     3
# 2018-08-06T03:27:11.000Z     3
# 2018-08-04T17:17:35.000Z     2
# 2017-12-26T00:40:39.000Z     2
# 2019-08-11T19:53:44.000Z     2
# 2018-08-18T14:47:52.000Z     2
# 2018-01-01T03:02:11.000Z     1
# Name: Data_Post, dtype: int64

# %% [markdown]
# ### Base Final

# %%
writer = pd.ExcelWriter('Bases/ig_Tiago.xlsx',
                        engine='xlsxwriter',options={'strings_to_urls': False}) #.format(staName2)
base.to_excel(writer)
writer.close()

# %% [markdown]
# ## Base Final

# %%
comment_details = {'profile name': names, 'comment': containerzera, 'time': time_post, 'Hora Post': horario_post*len(time_post), "likes": likes}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-c59d2aad7ee7> in <module>
# ----> 1 comment_details = {'profile name': names, 'comment': containerzera, 'time': time_post, 'Hora Post': horario_post*len(time_post), "likes": likes}
#
# NameError: name 'names' is not defined

# %%
df = pd.DataFrame(comment_details)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input
# 17  2019-11-17T18:17:30.000Z2019-11-17T18:17:30.00...
# 18  2019-11-17T18:17:30.000Z2019-11-17T18:17:30.00...

# %%
comment_details
# Out:
# {'profile name': 'gabrielravisantos',
#  'comment': 'Uma região que conta uma história, valeu Normandie!',
#  'time': '2019-11-17T18:18:47.000Z'}

# %%
name = container.find_element_by_class_name('_6lAjh').text

# %%
            container = c.find_element_by_class_name('C4VMK')
                name = container.find_element_by_class_name('_6lAjh').text
                content = container.find_element_by_tag_name('span').text
                content = content.replace('\n', ' ').strip().rstrip()
                time_of_post = browser.find_element_by_xpath('//a/time').get_attribute("datetime")
                comment_details = {'profile name': name, 'comment': content, 'time': time_of_post}
                print(comment_details)
                time.sleep(5)

# %%
def scrap_comments():

    global comments2
    global comment_id2
    global autor2
    global like_comentario2
    global hora2
    global autor_id2
    global n_comments2
    #global n_respostas2
    global comment_url2
    
    all_comments = driver.find_elements_by_xpath("//div[@data-commentid]")
    autor_comentario = driver.find_elements_by_class_name('_2b05')
    likes_comentario = driver.find_elements_by_class_name('_14va')
    hora_comentario = driver.find_elements_by_xpath("//abbr[@classas]")
    
    comments = []
    #n_resp_ = []
    autor = []
    like_comentario = []
    hora = []
    comment_url = []
    n_c = []
    
    for comment in all_comments:
        comments.append(comment.text)
    
    for autor0 in autor_comentario:
        autor.append(autor0.text)

    for like_comentario0 in likes_comentario:
        like_comentario.append(like_comentario0.text)

    for horario in hora_comentario:
        hora.append(horario.text)

    page_source = driver.page_source
    profile_bs = BeautifulSoup(page_source, 'lxml')

    name_pattern = re.compile(r'id=".+?"')

    comment_id = profile_bs.findAll('div', {'data-sigil': 'comment-body'})
    comment_id = name_pattern.findall(str(comment_id))

    comment_id = [re.sub(r'"|id=','', x) for x in comment_id]

    name_pattern = re.compile(r'ref=".+?"')
    #name_pattern = re.compile(r'(?:id=.+?&|<a href="\/.+?\?fnf|.+?\?rc)')

    autor_id = profile_bs.findAll('div', {'class': '_2b05'})
    autor_id = name_pattern.findall(str(autor_id))

    autor_id = [re.sub(r'"|ref=|profile.php\?id=|\&.*','', x) for x in autor_id]
    autor_id = [re.sub(r'\?fnf|\?rc=p|\/','', x) for x in autor_id]
    
    if comments==[]:
        n_c = ['']
    else:
        name_pattern = re.compile(r'ayk".+?respos')
        n_comments = profile_bs.findAll('div', {'class': '_2b04'})
        for rep in n_comments:
            aux = name_pattern.findall(str(rep))
            if aux == []:
                aux = ['']
            n_c = np.concatenate((n_c,aux))
        n_c = [re.sub(r'ayk">|respos|·| ','', x) for x in n_c]

    #name_pattern = re.compile(r'ayk".+?respos')

    #n_comments = profile_bs.findAll('div', {'class': '_2b04'})

    #for rep in n_comments:
    #    aux = name_pattern.findall(str(rep))
    #    if aux == []:
    #        aux = ['']
    #    n_c = np.concatenate((n_c,aux))

    #n_c = [re.sub(r'ayk">|respos|·| ','', x) for x in n_c]

    #n_respostas = profile_bs.findAll('span', {'class': '_4ayk'})

    for comment_url0 in profile_bs.findAll('a',  href = re.compile('comment')):
        comment_url.append(base_url + comment_url0['href'])
    
    #n_resp += np.concatenate((n_resp, list(np.tile('',len(comments)))))
    
    comment_url2 += comment_url
    #n_respostas2 += n_respostas
    n_comments2 += n_c
    comments2 += comments
    comment_id2 += comment_id
    autor2 += autor
    like_comentario2 += like_comentario
    hora2 += hora
    autor_id2 += autor_id

# %% [markdown]
# ### Scrap it

# %%
class Instagram_comments():
    def __init__(self):
         self.browser.get('https://www.instagram.com/'+username+'/?hl=en')
        
    def get_comments(self, url):
        self.browser.get(url)
        time.sleep(3)
        
        while True:
            try:
                self.load_more_comments = self.browser.find_element_by_class_name('glyphsSpriteCircle_add__outline__24__grey_9')
                self.action = ActionChains(self.browser)
                self.action.move_to_element(self.load_more_comments)
                self.load_more_comments.click()
                time.sleep(4)
                self.body_elem = self.browser.find_element_by_class_name('Mr508')
                for _ in range(100):
                    self.body_elem.send_keys(Keys.END)
                    time.sleep(3)
            except Exception as e:
                pass

            time.sleep(5)
            self.comment = self.browser.find_elements_by_class_name('gElp9 ')
            for c in self.comment:
                self.container = c.find_element_by_class_name('C4VMK')
                self.name = self.container.find_element_by_class_name('_6lAjh').text
                self.content = self.container.find_element_by_tag_name('span').text
                self.content = self.content.replace('\n', ' ').strip().rstrip()
                self.time_of_post = self.browser.find_element_by_xpath('//a/time').get_attribute("datetime")
                self.comment_details = {'profile name': self.name, 'comment': self.content, 'time': self.time_of_post}
                print(self.comment_details)
                time.sleep(5)
                
            return self.comment_details
# Out:
#   File "<ipython-input-43-64f9f71cb9e8>", line 4
#     def get_comments(self, url):
#     ^
# IndentationError: expected an indented block

# %%
Instagram_comments()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-2c5278ce9b02> in <module>
# ----> 1 Instagram_comments()
#
# <ipython-input-41-9e512c8382ec> in __init__(self)
#       1 class Instagram_comments():
#       2     def __init__(self):
# ----> 3          self.browser.get('https://www.instagram.com/'+username+'/?hl=en')
#       4
#       5     def get_comments(self, url):
#
# AttributeError: 'Instagram_comments' object has no attribute 'browser'

# %%
comment_details
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-d98e4c042c32> in <module>
# ----> 1 comment_details
#
# NameError: name 'comment_details' is not defined

# %% [markdown]
# ### Na mão

# %%
autor_comentario = driver.find_elements_by_class_name('_6lAjh')
autor = []
for autor0 in autor_comentario:
        autor.append(autor0.text)
        
autor

# %%
container = driver.find_elements_by_class_name('C4VMK')
container
containerzaum 
for i in container:
        containerzaum.append(i.text)
        
containerzaum

# coments = [i.split('\n', 1)[1].split("\n",1)[0] for i in containerzaum]
coments
# Out:
# ['"Hello, I\'m from Sevilla" Que viagem!',
#  'Cool kids 🔥',
#  'que grupo 💞',
#  '"Hello, I\'m from Sevilla" Que viagem!',
#  'Cool kids 🔥',
#  'que grupo 💞']

# %%
# No Facebook
all_comments = driver.find_elements_by_class_name("_6lAjh")
all_comments
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2c317683e12a1b6af4513707c511e025", element="9fa673b1-6f74-4f70-b5c3-559084caa517")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2c317683e12a1b6af4513707c511e025", element="b453e3ba-a60e-4d7a-add0-09690419d0d9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2c317683e12a1b6af4513707c511e025", element="abc693af-10b9-4c46-bdfa-fc02eea48746")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2c317683e12a1b6af4513707c511e025", element="b65a1b69-4e19-4811-8f7c-2dc15b8e01f5")>]

# %%
teste2= []
for i in driver.find_elements_by_class_name("_6lAjh"):
    teste2.append(i.text)
teste2
# Out:
# ['tiagopires98',
#  'tiagopires98',
#  'tiagopires98',
#  'gabrielravisantos',
#  'gabrielravisantos']

# %%
# You can simply use a CSS selector, and then print the text attribute of the span element:
teste2= []
for contact in driver.find_elements_by_css_selector('.C4VMK span'):
    teste2.append(contact.text)
teste2
#Comentários
            l1 = teste2[1::2]
print(l1)
#Autor
l2 = teste2[0::2]
print(l2)
# Out:
# ['Aquele final de semana no paraíso! Ganda Algarve!\n\n#Algarve #Portugal #Beach #Tasca #Paradise #caiaque #caves', 'Oh homi lindo do céu meu Deus ave maria cheia de graça o senhor é convosco', 'Deus no céu e eu na tua', '😍😍😍', '💯💯', 'Saudades lindao!', 'Que lugar toop 👏🏻👏🏻', 'Buéda fixe meu puto', 'Que paraíso, a vista é bonita tbm', 'Gostoso', 'Parabéns, que lugar foda ravis', 'The Portuguese ministry of tourism should pay you for modeling in their sites 😂😂🤘']
# ['gabrielravisantos', 'victoralbquerque', 'victoralbquerque', 'vivianneandradeb', 'bobnaestrada', 'brunomeloni_', 'anacsoutov', 'crismous', 'dariodescartes', 'rodrigoborba13', 'andre.brusco', 'ramyrmeile']

# %%
teste2= []
for i in driver.find_elements_by_xpath("//li/div/div/div/span"):
    teste2.append(i.text)

# %%
content = driver.page_source
soup = BeautifulSoup(content)
time = []

for i in soup.findAll('time'):
        if i.has_attr('datetime'):
            time.append(i['datetime'])
            print(i['datetime'])
            
time_post = time[1:]
time
# Out:
# 2017-08-05T13:59:16.000Z
# 2017-08-08T14:21:46.000Z
# 2018-08-14T02:33:55.000Z
# 2017-08-05T13:59:16.000Z
# ['2017-08-05T13:59:16.000Z',
#  '2017-08-08T14:21:46.000Z',
#  '2018-08-14T02:33:55.000Z',
#  '2017-08-05T13:59:16.000Z']

# %%
container = driver.find_elements_by_class_name('C4VMK')
container
containerzaum = []
for i in container:
    containerzaum.append(i.text)
containerzaum = containerzaum[1:]
containerzaum 

containerzera =[]
for i in containerzaum:
    containerzera.append(i[1:])
containerzera    

like_comentario = []
for cont in containerzera:
    like_comentario.append(cont[-12:])
print(like_comentario)
print(len(like_comentario))

# %%
links = driver.find_elements_by_class_name('_6lAjh ')
links
link_perfil= []
for i in links:
    link_perfil.append(i.find_element_by_css_selector('a').get_attribute('href'))
link_perfil
# Out:
# ['https://www.instagram.com/tiagopires98/',
#  'https://www.instagram.com/tiagopires98/',
#  'https://www.instagram.com/tiagopires98/']

# %%
#COMENTÁRIOS
teste2= []
for i in driver.find_elements_by_xpath("//li/div/div/div/span"):
    teste2.append(i.text)

# %%
name_pattern = re.compile(r'webelement', flags = re.M)
tipo_post_video = len(name_pattern.findall(str(driver.find_element_by_tag_name('video'))))
tipo_post_video

# %%
name_pattern = re.compile(r'webelement', flags = re.M)
tipo_post_photo = len(name_pattern.findall(str(driver.find_element_by_tag_name('img'))))
tipo_post_photo

# %%
tempo = driver.find_element_by_tag_name('time').get_attribute("datetime")
tempo
